# %% [markdown]
# Importing necessary libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Loading Dataset

# %%
df = pd.read_csv(r"C:\Users\paryn\Downloads\train.csv")

# %% [markdown]
# Checking basic details of the dataset

# %%
df.head()
# Out:
#     player_id                 name  age gender    country height  weight  \
# 0   PLID_4964           Keva Horan   23      M    Ukraine    6'2  176lbs
# 1  PLID_11234           Herma Tann   18      M     Russia   5'10  148lbs
# 2  PLID_19127         Eilene Kizer   16      F      Spain    6'2  172lbs
# 3  PLID_17467       Andrea Badgett   27      M      Chile   5'11  165lbs
# 4   PLID_9661  Jeremiah Bumbalough   19      F  Argentina    5'8  158lbs
#
#    ball_controlling_skills  body_reflexes  body_balance  ...  strong_foot  \
# 0                     77.0           58.0          47.0  ...        Right
# 1                     54.0           69.0          70.0  ...          Any
# 2                     34.0           43.0          45.0  ...         Left
# 3                     79.0           73.0          76.0  ...        Right
# 4                     47.0           61.0          74.0  ...        Right
#
#    behaviour_rating  matches_played  fitness_rating  trophies_won  \
# ...

# %%
df.shape
# Out:
# (13994, 30)

# %%
df.describe()
# Out:
#                 age  ball_controlling_skills  body_reflexes  body_balance  \
# count  13994.000000             13581.000000   13994.000000  13994.000000
# mean      21.135844                56.043958      61.934329     62.753323
# std        5.162719                16.787353      14.931963     14.203638
# min       16.000000                 5.000000      12.000000      9.000000
# 25%       17.000000                51.000000      54.000000     55.000000
# 50%       20.000000                61.000000      64.000000     65.000000
# 75%       24.000000                67.000000      72.000000     73.000000
# max       61.000000                95.000000      96.000000     97.000000
#
#        jumping_skills  penalties_conversion_rate  mental_strength  \
# count    13970.000000               13964.000000     13966.000000
# mean        63.612026                  48.495703        56.768366
# std         11.938712                  15.767506        11.977744
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13994 entries, 0 to 13993
# Data columns (total 30 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   player_id                  13994 non-null  object
#  1   name                       13994 non-null  object
#  2   age                        13994 non-null  int64
#  3   gender                     13975 non-null  object
#  4   country                    13994 non-null  object
#  5   height                     13994 non-null  object
#  6   weight                     13577 non-null  object
#  7   ball_controlling_skills    13581 non-null  float64
#  8   body_reflexes              13994 non-null  float64
#  9   body_balance               13994 non-null  float64
#  10  jumping_skills             13970 non-null  float64
#  11  penalties_conversion_rate  13964 non-null  float64
#  12  mental_strength            13966 non-null  float64
# ...

# %%
df.dtypes
# Out:
# player_id                     object
# name                          object
# age                            int64
# gender                        object
# country                       object
# height                        object
# weight                        object
# ball_controlling_skills      float64
# body_reflexes                float64
# body_balance                 float64
# jumping_skills               float64
# penalties_conversion_rate    float64
# mental_strength              float64
# goalkeeping_skills           float64
# defending_skills             float64
# passing_skills               float64
# dribbling_skills             float64
# shot_accuracy                float64
# body_strength_stamina        float64
# max_running_speed            float64
# strong_foot                   object
# behaviour_rating             float64
# matches_played               float64
# fitness_rating               float64
# trophies_won                 float64
# ...

# %%
df.columns
# Out:
# Index(['player_id', 'name', 'age', 'gender', 'country', 'height', 'weight',
#        'ball_controlling_skills', 'body_reflexes', 'body_balance',
#        'jumping_skills', 'penalties_conversion_rate', 'mental_strength',
#        'goalkeeping_skills', 'defending_skills', 'passing_skills',
#        'dribbling_skills', 'shot_accuracy', 'body_strength_stamina',
#        'max_running_speed', 'strong_foot', 'behaviour_rating',
#        'matches_played', 'fitness_rating', 'trophies_won', 'dedication_level',
#        'coaching', 'years_of_experience', 'no_of_disqualifications',
#        'selection'],
#       dtype='object')

# %% [markdown]
# Checking if the names of any player is repeated

# %%
df['name'].nunique()
# Out:
# 13994

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# Age Distribution

# %%
plt.hist(df['age'])
# Out:
# (array([7.270e+03, 3.498e+03, 2.583e+03, 4.960e+02, 6.000e+01, 3.000e+00,
#         0.000e+00, 1.200e+01, 1.800e+01, 5.400e+01]),
#  array([16. , 20.5, 25. , 29.5, 34. , 38.5, 43. , 47.5, 52. , 56.5, 61. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Most people have ages between 15 - 30

# %%
df.gender.value_counts()
# Out:
# M    6992
# F    6983
# Name: gender, dtype: int64

# %% [markdown]
# The number of Males is greater than number of females

# %%
Selected_countries = df[(df['selection']==1)]

# %%
Selected_countries
# Out:
#         player_id               name  age gender        country height  \
# 0       PLID_4964         Keva Horan   23      M        Ukraine    6'2
# 2      PLID_19127       Eilene Kizer   16      F          Spain    6'2
# 3      PLID_17467     Andrea Badgett   27      M          Chile   5'11
# 7      PLID_20082         Joyce Boxx   21      F  United States   5'11
# 8      PLID_22917     Josette Mcgrew   25      M          Italy    6'0
# ...           ...                ...  ...    ...            ...    ...
# 13986  PLID_21441         Edna Towne   16      M         France    6'0
# 13987  PLID_19280    Phoebe Vancleve   25      F       Colombia   5'10
# 13989  PLID_10956       Viva Stepney   20      M        Uruguay    6'0
# 13991   PLID_5193  Marylouise Mosley   17      M          Japan    6'0
# 13992  PLID_12173     Teri Escamilla   20      F        Ukraine   5'10
#
#        weight  ball_controlling_skills  body_reflexes  body_balance  ...  \
# ...

# %%
country_counts = df['country'].value_counts()

# Create a count plot
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='country', order=country_counts.index[0:20], palette='viridis')
plt.title('Number of Selections by Country')
plt.xlabel('Country')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# The players from the Country England is selected more. Then Germany, Spain, France etc

# %%
plt.figure(figsize=(20, 12))
sns.heatmap(df.corr(),annot=True)
# Out:
# C:\Users\paryn\AppData\Local\Temp\ipykernel_14144\2216618576.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# <Axes: >

# %% [markdown]
# The features - Behaviour rating and Mental strength has high positive correlation with target column.
# The feature years of experience has a negative correlation with target.

# %%
coaching = df['coaching'].value_counts()

# %%
coaching
# Out:
# Academy        9390
# Talent Hunt    1993
# Unknown        1360
# Source         1126
# Name: coaching, dtype: int64

# %%
plt.figure(figsize=(5, 5))
plt.pie(coaching, labels=coaching.index ,autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
plt.title('Coaching Distribution Among Players')

# Equal aspect ratio ensures that pie is drawn as a circle.
plt.axis('equal')

# Show the plot
plt.show()

# %% [markdown]
# The players have had coaching from Academy than other coaching centers.

# %%
num = [feature for feature in df.columns if df[feature].dtypes!='O']

for i in num:
    plt.figure()
    plt.hist(df[i])
    plt.title(i)
    plt.show()

# %% [markdown]
# The above diagrams show the frequency distribution of every numerical columns in the dataset.

# %%
plt.figure(figsize=(7, 5))
sns.countplot(data=df, x='selection', palette='Set2')
plt.title('Distribution of Selected and Not Selected Players')
plt.xlabel('Selection Status')
plt.ylabel('Count')
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# The number of selected Players is greater than not selected ones.

# %%
sns.countplot(x=df['gender'],hue=df['selection'])
plt.title('Player Selection by Gender')
# Out:
# Text(0.5, 1.0, 'Player Selection by Gender')

# %%
sorted_df = df.sort_values(by='years_of_experience', ascending=False)

# Select the top 10 players
top_10_players = sorted_df.head(10)

# Create a bar plot
plt.figure(figsize=(10, 6))
sns.barplot(data=top_10_players, x='name', y='years_of_experience', hue='selection', palette='Set2')
plt.title('Top 10 Players by Experience and Selection Status')
plt.xlabel('Player')
plt.ylabel('Years of Experience')
plt.xticks(rotation=45)
plt.tight_layout()

# Show the plot
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, x='dedication_level', y='fitness_rating', palette='Set2')
plt.title('Box Plot: Dedication Level vs Fitness Rating')
plt.xlabel('Dedication Level')
plt.ylabel('Fitness Rating')
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# Handling Null Values

# %%
df.isna().sum()
# Out:
# player_id                      0
# name                           0
# age                            0
# gender                        19
# country                        0
# height                         0
# weight                       417
# ball_controlling_skills      413
# body_reflexes                  0
# body_balance                   0
# jumping_skills                24
# penalties_conversion_rate     30
# mental_strength               28
# goalkeeping_skills             0
# defending_skills               0
# passing_skills                 0
# dribbling_skills               0
# shot_accuracy                572
# body_strength_stamina          0
# max_running_speed              0
# strong_foot                  552
# behaviour_rating             703
# matches_played               666
# fitness_rating               695
# trophies_won                   0
# dedication_level               0
# coaching                     125
# years_of_experience          144
# ...

# %%
df['weight'] = df['weight'].str.replace('lbs', '')

# Convert the weight column to numeric values
df['weight'] = pd.to_numeric(df['weight'])

# %%
df.head()
# Out:
#     player_id                 name  age gender    country height  weight  \
# 0   PLID_4964           Keva Horan   23      M    Ukraine    6'2   176.0
# 1  PLID_11234           Herma Tann   18      M     Russia   5'10   148.0
# 2  PLID_19127         Eilene Kizer   16      F      Spain    6'2   172.0
# 3  PLID_17467       Andrea Badgett   27      M      Chile   5'11   165.0
# 4   PLID_9661  Jeremiah Bumbalough   19      F  Argentina    5'8   158.0
#
#    ball_controlling_skills  body_reflexes  body_balance  ...  strong_foot  \
# 0                     77.0           58.0          47.0  ...        Right
# 1                     54.0           69.0          70.0  ...          Any
# 2                     34.0           43.0          45.0  ...         Left
# 3                     79.0           73.0          76.0  ...        Right
# 4                     47.0           61.0          74.0  ...        Right
#
#    behaviour_rating  matches_played  fitness_rating  trophies_won  \
# ...

# %%
def convert_height(height):
    feet = int(height.split("'")[0])
    inches = int(height.split("'")[1].replace('"', ''))
    total_inches = feet * 12 + inches
    return total_inches

df['height'] = df['height'].apply(convert_height)

# %%
df.head()
# Out:
#     player_id                 name  age gender    country  height  weight  \
# 0   PLID_4964           Keva Horan   23      M    Ukraine      74   176.0
# 1  PLID_11234           Herma Tann   18      M     Russia      70   148.0
# 2  PLID_19127         Eilene Kizer   16      F      Spain      74   172.0
# 3  PLID_17467       Andrea Badgett   27      M      Chile      71   165.0
# 4   PLID_9661  Jeremiah Bumbalough   19      F  Argentina      68   158.0
#
#    ball_controlling_skills  body_reflexes  body_balance  ...  strong_foot  \
# 0                     77.0           58.0          47.0  ...        Right
# 1                     54.0           69.0          70.0  ...          Any
# 2                     34.0           43.0          45.0  ...         Left
# 3                     79.0           73.0          76.0  ...        Right
# 4                     47.0           61.0          74.0  ...        Right
#
#    behaviour_rating  matches_played  fitness_rating  trophies_won  \
# ...

# %%
num_with_na=['weight', 'ball_controlling_skills', 'jumping_skills', 'penalties_conversion_rate', 'mental_strength',
            'shot_accuracy','behaviour_rating', 'matches_played', 'fitness_rating','years_of_experience' ]
for i in num_with_na:
    df[i]=df[i].fillna(df[i].median())

# %%
cat_with_na = ['gender','strong_foot','coaching']
for i in cat_with_na:
    df[i]=df[i].fillna(df[i].mode()[0])

# %%
df.isna().sum()
# Out:
# player_id                    0
# name                         0
# age                          0
# gender                       0
# country                      0
# height                       0
# weight                       0
# ball_controlling_skills      0
# body_reflexes                0
# body_balance                 0
# jumping_skills               0
# penalties_conversion_rate    0
# mental_strength              0
# goalkeeping_skills           0
# defending_skills             0
# passing_skills               0
# dribbling_skills             0
# shot_accuracy                0
# body_strength_stamina        0
# max_running_speed            0
# strong_foot                  0
# behaviour_rating             0
# matches_played               0
# fitness_rating               0
# trophies_won                 0
# dedication_level             0
# coaching                     0
# years_of_experience          0
# no_of_disqualifications      0
# selection                    0
# ...

# %%
num = [feature for feature in df.columns if df[feature].dtypes!='O']

for i in num:
    plt.figure()
    plt.boxplot(df[i])
    plt.title(i)
    plt.show()

# %%
df[df['age']>55]
# Out:
#         player_id                   name  age gender              country  \
# 607     PLID_7006            Hilde Curry   57      F                Chile
# 668    PLID_15475     Yang Degraffenreid   57      M                Italy
# 712    PLID_20828           Cedrick Holz   57      M               Brazil
# 714    PLID_17792       William Rockhill   57      M        United States
# 1458    PLID_4113      Jackson Broderson   57      M   Bosnia Herzegovina
# 1669    PLID_6899          Sonya Lizaola   57      F              Uruguay
# 2117   PLID_15515       Franklin Godfrey   57      F         Saudi Arabia
# 2225   PLID_19927       Francis Musgrove   57      M                Chile
# 2244   PLID_12095        Brandon Patrick   57      M              England
# 2835    PLID_7903        Giselle Dudgeon   59      F                Chile
# 3607    PLID_2285         Merideth Nitta   60      F                Japan
# 4139   PLID_12467              Nelda Kuo   57      F               Brazil
# ...

# %%
df[df['age']>55].index
# Out:
# Int64Index([  607,   668,   712,   714,  1458,  1669,  2117,  2225,  2244,
#              2835,  3607,  4139,  4907,  5177,  5231,  5704,  6000,  6155,
#              6227,  6410,  6496,  6618,  7172,  7178,  7664,  7853,  8309,
#              8833,  8859,  8970,  9036,  9072,  9119,  9139,  9184,  9482,
#              9706,  9744,  9815, 10234, 10310, 10340, 10657, 10778, 10945,
#             11254, 11594, 11853, 12020, 12096, 12180, 12372, 12403, 12702,
#             12751, 13020, 13237, 13344],
#            dtype='int64')

# %%
df= df.drop([  607,   668,   712,   714,  1458,  1669,  2117,  2225,  2244,
             2835,  3607,  4139,  4907,  5177,  5231,  5704,  6000,  6155,
             6227,  6410,  6496,  6618,  7172,  7178,  7664,  7853,  8309,
             8833,  8859,  8970,  9036,  9072,  9119,  9139,  9184,  9482,
             9706,  9744,  9815, 10234, 10310, 10340, 10657, 10778, 10945,
            11254, 11594, 11853, 12020, 12096, 12180, 12372, 12403, 12702,
            12751, 13020, 13237, 13344])

# %%
df[df['height']>1000]
# Out:
#         player_id               name  age gender         country  height  \
# 6061   PLID_10358  Sade Fenstermaker   23      F  Korea Republic    1188
# 6869   PLID_21416  Evelina Martensen   23      F          Norway    1069
# 11463  PLID_14653   Evelina Primeaux   24      F           Chile    1188
# 13799  PLID_15785     Desire Mcmanis   16      M           Spain    1069
#
#        weight  ball_controlling_skills  body_reflexes  body_balance  ...  \
# 6061    152.0                     60.0           54.0          56.0  ...
# 6869    179.0                     66.0           68.0          65.0  ...
# 11463   167.0                      5.0           63.0          65.0  ...
# 13799   154.0                     63.0           65.0          73.0  ...
#
#        strong_foot  behaviour_rating  matches_played  fitness_rating  \
# 6061         Right               5.8             0.0             8.1
# 6869         Right               6.6             0.0             9.7
# ...

# %%
df[df['height']>1000].index
# Out:
# Int64Index([6061, 6869, 11463, 13799], dtype='int64')

# %%
df= df.drop([6061, 6869, 11463, 13799])

# %%
df.shape
# Out:
# (13932, 30)

# %%
df = df.drop(['player_id','name','country','coaching'],axis=1)

# %%
df.shape
# Out:
# (13932, 26)

# %%
df.columns
# Out:
# Index(['age', 'gender', 'height', 'weight', 'ball_controlling_skills',
#        'body_reflexes', 'body_balance', 'jumping_skills',
#        'penalties_conversion_rate', 'mental_strength', 'goalkeeping_skills',
#        'defending_skills', 'passing_skills', 'dribbling_skills',
#        'shot_accuracy', 'body_strength_stamina', 'max_running_speed',
#        'strong_foot', 'behaviour_rating', 'matches_played', 'fitness_rating',
#        'trophies_won', 'dedication_level', 'years_of_experience',
#        'no_of_disqualifications', 'selection'],
#       dtype='object')

# %%
cat = [feature for feature in df.columns if df[feature].dtypes=='O']

# %%
cat
# Out:
# ['gender', 'strong_foot', 'dedication_level']

# %%
from sklearn.preprocessing import LabelEncoder
for x in cat:
    le=LabelEncoder()
    df[x]=le.fit_transform(df[x])

# %%
df.head()
# Out:
#    age  gender  height  weight  ball_controlling_skills  body_reflexes  \
# 0   23       1      74   176.0                     77.0           58.0
# 1   18       1      70   148.0                     54.0           69.0
# 2   16       0      74   172.0                     34.0           43.0
# 3   27       1      71   165.0                     79.0           73.0
# 4   19       0      68   158.0                     47.0           61.0
#
#    body_balance  jumping_skills  penalties_conversion_rate  mental_strength  \
# 0          47.0            59.0                       41.0             73.0
# 1          70.0            62.0                       53.0             43.0
# 2          45.0            69.0                       49.0             45.0
# 3          76.0            86.0                       81.0             80.0
# 4          74.0            57.0                       49.0             35.0
#
#    ...  max_running_speed  strong_foot  behaviour_rating  matches_played  \
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
# Initialize the MinMaxScaler
scaler = MinMaxScaler()

# Fit and transform the scaler on the dataset
scaled = scaler.fit_transform(df)

# Create a new DataFrame with scaled values
df = pd.DataFrame(scaled, columns=df.columns)

# %%
df.head()
# Out:
#         age  gender    height    weight  ball_controlling_skills  \
# 0  0.179487     1.0  0.445312  0.496241                 0.797753
# 1  0.051282     1.0  0.414062  0.285714                 0.539326
# 2  0.000000     0.0  0.445312  0.466165                 0.314607
# 3  0.282051     1.0  0.421875  0.413534                 0.820225
# 4  0.076923     0.0  0.398438  0.360902                 0.460674
#
#    body_reflexes  body_balance  jumping_skills  penalties_conversion_rate  \
# 0       0.547619      0.431818        0.555556                   0.400000
# 1       0.678571      0.693182        0.592593                   0.541176
# 2       0.369048      0.409091        0.679012                   0.494118
# 3       0.726190      0.761364        0.888889                   0.870588
# 4       0.583333      0.738636        0.530864                   0.494118
#
#    mental_strength  ...  max_running_speed  strong_foot  behaviour_rating  \
# ...

# %%
x=df.drop('selection',axis=1)
y=df['selection']

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr.fit(xtrain,ytrain)
ypredlr=lr.predict(xtest)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,precision_score,recall_score,f1_score
print("Accuracy=",accuracy_score(ytest,ypredlr))
print("Precision=",precision_score(ytest,ypredlr))
print("recall_score=",recall_score(ytest,ypredlr))
print("f1_score=",f1_score(ytest,ypredlr))
# Out:
# Accuracy= 0.7818442770003589
# Precision= 0.7939698492462312
# recall_score= 0.8186528497409327
# f1_score= 0.8061224489795918

# %%
confusion_matrix(ytest,ypredlr)
# Out:
# array([[ 915,  328],
#        [ 280, 1264]], dtype=int64)

# %%
from sklearn.neighbors import KNeighborsClassifier
metric = []
neighbors = np.arange(2,15)

for k in neighbors:
    classifier = KNeighborsClassifier(n_neighbors = k, metric = 'minkowski',p=2)
    classifier.fit(xtrain,ytrain)
    y_pred_knn = classifier.predict(xtest)
    acc = accuracy_score(ytest,y_pred_knn)
    metric.append(acc)

# %%
plt.plot(neighbors,metric,"o-")
plt.xlabel("kvalue")
plt.xlabel("accuracy")
plt.grid()

# %%
classifier = KNeighborsClassifier(n_neighbors = 11, metric = 'minkowski',p=2)
classifier.fit(xtrain,ytrain)
y_pred_knn = classifier.predict(xtest)

# %%
print("Accuracy=",accuracy_score(ytest,y_pred_knn))
print("Precision=",precision_score(ytest,y_pred_knn))
print("recall_score=",recall_score(ytest,y_pred_knn))
print("f1_score=",f1_score(ytest,y_pred_knn))
# Out:
# Accuracy= 0.761750986724076
# Precision= 0.7784810126582279
# recall_score= 0.7966321243523317
# f1_score= 0.7874519846350833

# %%
confusion_matrix(ytest,y_pred_knn)
# Out:
# array([[ 893,  350],
#        [ 314, 1230]], dtype=int64)

# %%
from sklearn.svm import SVC
svmclf=SVC(kernel="linear")
svmclf.fit(xtrain,ytrain)
# Out:
# SVC(kernel='linear')

# %%
ypredsvm=svmclf.predict(xtest)
print("Accuracy is:",accuracy_score(ytest,ypredsvm))
print("f1_score=",f1_score(ytest,ypredsvm))
# Out:
# Accuracy is: 0.7857911733046287
# f1_score= 0.8076055430228811

# %%
print(confusion_matrix(ytest,ypredsvm))
# Out:
# [[ 937  306]
#  [ 291 1253]]

# %%
from sklearn.tree import DecisionTreeClassifier
dt_clf=DecisionTreeClassifier()
dt_clf.fit(xtrain,ytrain)
ypreddt=dt_clf.predict(xtest)

# %%
print('Accuracy is:',accuracy_score(ytest,ypreddt))
print("f1_score=",f1_score(ytest,ypreddt))
# Out:
# Accuracy is: 0.7847147470398278
# f1_score= 0.8055735580038884

# %%
from sklearn.ensemble import RandomForestClassifier
rf_clf=RandomForestClassifier()
rf_clf.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier()

# %%
ypredrf=rf_clf.predict(xtest)
print('Accuracy:',accuracy_score(ytest,ypredrf))
print("f1_score=",f1_score(ytest,ypredrf))
# Out:
# Accuracy: 0.8464298528884104
# f1_score= 0.8615782664941785

# %%
model = RandomForestClassifier(n_estimators=300,criterion='entropy',max_features='sqrt',
                               min_samples_leaf=10, random_state=100).fit(xtrain,ytrain)

# %%
pred2=model.predict(xtest)
from sklearn.model_selection import RandomizedSearchCV
n_estimators = [int(x) for x in np.linspace(start=200, stop=2000, num=10)]
max_features= ['auto', 'sqrt', 'log2']
max_depth=  [int(x) for x in np.linspace(start=10, stop=1000, num=10)]
min_samples_split = [2,5,10,14]
min_samples_leaf = [1,2,4,6,8]

# %%
random_grid= {'n_estimators':n_estimators, 'max_features':max_features, 'max_depth':max_depth,
              'min_samples_split': min_samples_split, 'min_samples_leaf':min_samples_leaf,
              'criterion':['entropy','gini','log_loss']}
rf= RandomForestClassifier()

# %%
rf_randomcv = RandomizedSearchCV(estimator=rf,param_distributions=random_grid,n_iter=100,
                                 cv=3, verbose=2, random_state=100, n_jobs=1)
rf_randomcv.fit(xtrain,ytrain)
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [CV] END criterion=entropy, max_depth=1000, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.1s
# [CV] END criterion=entropy, max_depth=1000, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.9s
# [CV] END criterion=entropy, max_depth=1000, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.9s
# [CV] END criterion=log_loss, max_depth=340, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=1600; total time=  19.8s
# [CV] END criterion=log_loss, max_depth=340, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=1600; total time=  20.8s
# [CV] END criterion=log_loss, max_depth=340, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=1600; total time=  21.9s
# ...

# %%
rf_randomcv.best_params_

# %%
best= rf_randomcv.best_estimator_

# %%
pred3= best.predict(xtest)

print(confusion_matrix(ytest,pred3))
print(accuracy_score(ytest,pred3))
